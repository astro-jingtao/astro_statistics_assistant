# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from asa.plot_methods import plot_line
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# %%
kwargs = {'color': 'red', 'linestyle': '--'}

# %%
plot_line(x=2, **kwargs)
plot_line(y=3, **kwargs)
plot_line(p1=(1, 1), p2=(3, 7), **kwargs)
plot_line(p1=(1, 1), k=1, **kwargs)
plot_line(p1=(1, 1), b=-1, **kwargs)
plot_line(k=1, b=-1, **kwargs)
plt.plot(x, y)
