# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from asa.dataset import Dataset

# %%
x = np.random.normal(size=1000)
y = x**2 + np.random.normal(size=1000)
z = np.log(np.abs(x + y)) + np.random.normal(size=1000)

# %%
data = np.array([x, y, z]).T

# %%
dataset = Dataset(data, ['x', 'y', 'z'], ['x', 'y', 'z'])

# %%
dataset.scatter(
    'x',
    ['y', 'z'],
    #range=([[-3, 3], [-10, 10]]),
    subplots_kwargs={'figshape': (1, 2)},
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 dataset.scatter(
#       2     'x',
#       3     ['y', 'z'],
#       4     #range=([[-3, 3], [-10, 10]]),
#       5     subplots_kwargs={'figshape': (1, 2)},
#       6 )
#
# File ~/Desktop/Research/mylib/astro_statistics_assistant/asa/dataset.py:358, in Dataset.scatter(self, x_names, y_names, subsample, axes, subplots_kwargs, **kwargs)
#     350 def scatter(self,
#     351             x_names,
#     352             y_names,
#    (...)
#     355             subplots_kwargs=None,
#     356             **kwargs):
# --> 358     self.plot_xygeneral('scatter',
#     359                         x_names,
#     360                         y_names,
#     361                         subsample=subsample,
#     362                         axes=axes,
#     363                         subplots_kwargs=subplots_kwargs,
#     364                         **kwargs)
#
# File ~/Desktop/Research/mylib/astro_statistics_assistant/asa/dataset.py:302, in Dataset.plot_xygeneral(self, kind, x_names, y_names, subsample, axes, subplots_kwargs, **kwargs)
#     296     self.method_mapping[kind](x_names[j],
#     297                               y_names[0],
#     298                               ax,
#     299                               subsample=subsample,
#     300                               **this_kwargs)
#     301 elif scatter_type == 'y':
# --> 302     self.method_mapping[kind](x_names[0],
#     303                               y_names[i],
#     304                               ax,
#     305                               subsample=subsample,
#     306                               **this_kwargs)
#
# File ~/Desktop/Research/mylib/astro_statistics_assistant/asa/dataset.py:173, in Dataset._scatter(self, x_name, y_name, ax, subsample, **kwargs)
#     171 if weights is None: weights = np.ones_like(x)
#     172 _subsample = self.get_subsample(subsample)
# --> 173 plot_scatter(x[_subsample], y[_subsample], ax=ax, weights=weights[_subsample], **kwargs)
#     174 ax.set_xlabel(x_name)
#     175 ax.set_ylabel(y_name)
#
# File ~/Desktop/Research/mylib/astro_statistics_assistant/asa/plot_methods.py:226, in plot_scatter(x, y, fig, ax, range, auto_p, weights, plot_kwargs)
#     223 if weights is None:
#     224     weights = np.ones_like(x)
# --> 226 ax.scatter(x[is_in_range], y[is_in_range], **plot_kwargs)
#
# TypeError: scatter() argument after ** must be a mapping, not NoneType
