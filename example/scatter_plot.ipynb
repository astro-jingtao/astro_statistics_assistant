# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from asa.dataset import Dataset

# %%
x = np.random.normal(size=1000)
y = x**2 + np.random.normal(size=1000)
z = np.log(np.abs(x + y)) + np.random.normal(size=1000)

# %%
data = np.array([x, y, z]).T

# %%
dataset = Dataset(data, ['x', 'y', 'z'], ['x', 'y', 'z'])

# %%
dataset.scatter(
    'x',
    ['y', 'z'],
    #range=([[-3, 3], [-10, 10]]),
    subplots_kwargs={'figshape': (1, 2)},
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dataset.scatter(
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     'x',
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     ['y', 'z'],
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     #range=([[-3, 3], [-10, 10]]),
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     subplots_kwargs={'figshape': (1, 2)},
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d65746973227d/home/jingtao/software/workspace/astro_statistics_assistant/example/scatter_plot.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> )
#
# File /work/jingtao/workspace/astro_statistics_assistant/asa/dataset.py:358, in Dataset.scatter(self, x_names, y_names, axes, subplots_kwargs, **kwargs)
#     351 def scatter(self,
#     352             x_names,
#     353             y_names,
#     354             axes=None,
#     355             subplots_kwargs=None,
#     356             **kwargs):
# --> 358     self.plot_xygeneral('scatter',
#     359                         x_names,
#     360                         y_names,
#     361                         axes=axes,
#     362                         subplots_kwargs=subplots_kwargs,
#     363                         **kwargs)
#
# File /work/jingtao/workspace/astro_statistics_assistant/asa/dataset.py:307, in Dataset.plot_xygeneral(self, kind, x_names, y_names, axes, subplots_kwargs, **kwargs)
#     304     elif scatter_type == 'y':
#     305         this_kwargs[key] = each_key[key][0][i]
# --> 307 self.method_mapping[kind](x_names[j],
#     308                           y_names[i],
#     309                           ax,
#     310                           **this_kwargs)
#
# File /work/jingtao/workspace/astro_statistics_assistant/asa/dataset.py:186, in Dataset._scatter(self, x_name, y_name, ax, subsample, **kwargs)
#     183 weights = self.get_data_by_name(weights) if isinstance(
#     184     weights, str) else weights
#     185 _weights = weights[_subsample] if weights is not None else None
# --> 186 plot_scatter(x[_subsample], y[_subsample], ax=ax, weights=_weights, **kwargs)
#     187 ax.set_xlabel(x_name)
#     188 ax.set_ylabel(y_name)
#
# File /work/jingtao/workspace/astro_statistics_assistant/asa/plot_methods.py:226, in plot_scatter(x, y, fig, ax, range, auto_p, weights, plot_kwargs)
#     223 if weights is None:
#     224     weights = np.ones_like(x)
# --> 226 ax.scatter(x[is_in_range], y[is_in_range], **plot_kwargs)
#
# TypeError: matplotlib.axes._axes.Axes.scatter() argument after ** must be a mapping, not NoneType
