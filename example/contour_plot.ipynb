# %%
import numpy as np
from asa.dataset import Dataset

# %%
x = np.random.normal(size=1000)
y = x**2 + np.random.normal(size=1000)
z = np.log(np.abs(x + y)) + np.random.normal(size=1000)

# %%
data = np.array([x, y, z, x > 0, np.abs(y)]).T

# %%
dataset = Dataset(data, ['x', 'y', 'z', 'xg0', 'absy'], ['x', 'y', 'z', 'xg0', 'absy'])

# %%
dataset.contour('x', ['y', 'z'], subplots_kwargs={'figshape': (1, 2)})

# %%
dataset.contour('x', ['y', 'log10@absy'], subplots_kwargs={'figshape': (1, 2)})

# %%
dataset.contour('x', ['y', 'z'], subplots_kwargs={'figshape': (1, 2)}, color_each=['red', 'blue'])

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample=x > 0)

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample='xg0')

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample='x>0')

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample='-1.5<x<1.5')

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample=x > 0, kde_smooth=True)

# %%
dataset.contour('x', ['y', 'z'],
                subplots_kwargs={'figshape': (1, 2)},
                color_each=['red', 'blue'],
                subsample=x > 0, smooth=2)
